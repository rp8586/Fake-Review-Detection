# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.read_gml('BooksGraphTest_0.75.gml')
nx.info(G)
# Out:
# 'Graph with 685 nodes and 10232 edges'

# %%
nx.density(G)
# Out:
# 0.043676100226234686

# %%
nx.number_connected_components(G)
# Out:
# 69

# %%
import matplotlib.pyplot as plt
import seaborn as sns
G.degree()
y= list(dict(G.degree()).values())
x=list(dict(G.degree()).keys())
plt.figure(figsize=(20,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 685 artists>

# %%
real=list(dict(G.degree()).values())
from statistics import mean
mean(real)
# Out:
# 29.874452554744526

# %%
nx.average_clustering(G)
# Out:
# 0.4273425106466061

# %%
nx.transitivity(G)
# Out:
# 0.38880876701930833

# %%
degrees = {node:val for (node, val) in G.degree()}
degrees
# Out:
# {'... families that are affected by memory disorder in a loved one. I had the privilege of working with ...': 8,
#  '....we will stay with the loyal SS in this village, lilke good Germans.': 0,
#  '1421': 41,
#  '2 steps forward, 10 steps back': 8,
#  '3.5 stars': 0,
#  '5 Stars !': 22,
#  'A "must-have" for every Needleworker': 12,
#  'A Bewitching Book!': 22,
#  'A Complete Story': 2,
#  'A Day in the Life of a Century': 19,
#  'A Gem of a Book': 24,
#  'A Great Personal Story about Successfully dealing with IBS.': 142,
#  'A MUST READ!!!': 29,
#  'A Moving Story': 5,
#  'A Must Have for Attorneys but Good for Others as Well': 62,
#  "A Professional's way of Studying": 5,
#  'A Really Good Read': 84,
#  'A Road to Recovery and New Beginnings': 23,
#  'A Series of 66 Flashes': 9,
#  'A Sweet Study Deal': 20,
#  'A Thriller about a Different Time and Place': 2,
#  'A Truly Enlightened Book ♥': 42,
#  "A Wonderful Woman's Journey into Peace": 45,
#  'A beautiful story - a no spoilers review': 14,
#  'A book everyone should read': 50,
#  'A book that will leave you with a lot to think about in the end': 61,
#  'A delightful book and an excellent companion to reading any book by and about Jane Austen': 7,
#  'A disappointment': 64,
#  'A fair review of a controversial life.': 32,
#  'A favorite book': 16,
#  'A fun read.': 29,
#  'A great book': 19,
#  'A little dated, but still worthwhile': 118,
#  'A lovely warm memory of a Summer caring for Lily': 1,
#  'A marvelous spoof': 1,
#  'A modern day philosopher!': 49,
#  'A must have guide!!': 10,
#  'A must read!': 3,
#  'A nice read if you read the first book for the backstory.': 137,
#  "A pale sequal to Ender's game": 64,
#  'A quality hard back Bible': 0,
#  'A real character': 25,
#  'A really good read': 12,
#  'A reference book to PMBOK': 58,
#  'A story of an unlikely hero.': 118,
#  'A wonderful snapshot of Greek Orthodox life.': 0,
#  'ANGELS ARE PROMINENT IN ALL THE MAJOR RELIGIONS AND THE HOLY BOOKS OF EACH': 11,
#  'Abusive': 2,
#  "Admiral Gorshkov: Russia's Mahan and Rickover?": 0,
#  'All real and no fluff!': 100,
#  'All you need to Know': 19,
#  'All-time favorite': 76,
#  'Amazing creation!!!!!!': 27,
#  'Amazing!!!!!': 24,
#  'An absolute delight!': 65,
#  'An absolutely EXCELLENT read for anyone interested in the Civil War': 21,
#  'An easy-to-read explanation of acid reflux with a clear action plan': 1,
#  'An essential work for your research/study library for any grad student - especially for those in doctoral programs.': 1,
#  'An excellent story': 54,
#  'An intelligent and witty read!': 15,
#  'An old book but not out of date by any means!': 16,
#  'An uncommon book': 9,
#  'An unrivaled mysterious story': 26,
#  "And she asks questions and follows the story line pretty well. I'd say this book isn't that well ...": 21,
#  'Another amazing book by Simi': 32,
#  'Appreciated gift': 0,
#  'Arrived on time, in new condition, but the ...': 16,
#  'Art Content and all that Jazz': 25,
#  'Attractive child novel': 36,
#  'Aventura en biografia': 1,
#  'Avoid this and all books from Emereo': 1,
#  'Awesome': 32,
#  'Awesome Book!!': 55,
#  'Awesome book!': 22,
#  'Awesome book.': 35,
#  'Awesome guide': 71,
#  'Awesome!': 5,
#  'BEST  IN  A  LONG  TIME': 17,
#  'BEST EXPERIENCE EVER': 34,
#  'BLOODSHOT!': 55,
#  'BORING!': 3,
#  "Be Stylin'": 18,
#  'Beautiful and real': 66,
#  'Beautiful poetry for those who love the genre and return ...': 15,
#  'Beautifully Atmospheric': 1,
#  "Beginner's lack": 19,
#  'Best Find In A Long While!': 151,
#  'Best For Those Who Work in HR Departments': 15,
#  'Best basic guidelines book for survival': 28,
#  'Best book for teaching': 20,
#  'Best book to study cardiovascular system': 6,
#  "Best dummies book I've purchased": 0,
#  'Better Brain, Better Me!': 80,
#  'Better priced than a day long professsional training.': 74,
#  'Better, But Not Excellent': 38,
#  'Big Fan': 33,
#  'Blah': 9,
#  'Book Review': 18,
#  'Book by Mr. Bradley much better.': 28,
#  'Book is ok': 80,
#  'Books for Album Covers': 9,
#  'Boring read explaining the airport process': 37,
#  'Both more and less than the sum of its parts': 76,
#  'Bought as birthday gift for son . Very happy with camera.': 3,
#  'Bowling for Whitman': 1,
#  'Brilliantly Crafted': 59,
#  'Buffett is awesome': 1,
#  'Buried Treasures Book': 6,
#  'Businesses that are looking to build a superb online marketing campaign including a fantastic website that is sure to land them': 4,
#  'CAMP book , not for PMP': 72,
#  'Can anyone please check the dog pound?': 3,
#  'Can talk to the boys about cigars now': 0,
#  'Candid- and Depressing': 65,
#  'Cane river review': 9,
#  'Captivating and Inspirational Book!': 46,
#  'Change in POV works despite inconsistencies!': 107,
#  'Child friendly Christmas story': 35,
#  'Classic': 0,
#  'Coloring Book': 7,
#  'Comforting': 10,
#  "Couldn't Put it Down": 112,
#  "Couldn't have been much better!": 6,
#  'Critical Secrets': 73,
#  'Crossword book - see what you get': 10,
#  'Daughter Of Africa': 1,
#  'Dear author!': 17,
#  'Dear me': 1,
#  'Decent one': 53,
#  'Decent read until the end': 68,
#  'Deeply entertaining in a superfluous sort of way': 37,
#  "Delightful Children's Book": 3,
#  'Descubri Mis Talentos y Mis Habilidades': 1,
#  'Diamond From The Rough': 4,
#  "Didn't hurt": 35,
#  "Didn't resonate with me.": 29,
#  'Disapointing': 25,
#  'Disappointed': 27,
#  'Disappointing': 66,
#  "Do you want to live for God's Kingdom?": 53,
#  "Doesn't disappoint! Love Chelsea Handler!!": 29,
#  "Don't Get Burned by Following Jesus": 73,
#  "Don't tell Harold Bloom I read this": 66,
#  "Duke Matches or Tops Teachout's Book on Satchmo": 0,
#  'Dwayne Johnson - The Rock Says': 0,
#  'ESV Single Column Legacy Bible': 1,
#  'Easy to understand': 126,
#  'Eh, its ok': 19,
#  'Elizabeth George Is in Top Form!': 52,
#  'Emma and Granny Face Dangers of Flesh and Ghost': 7,
#  'Engaging Read': 46,
#  'Enjoyed it': 106,
#  'Epic!': 5,
#  'Every Parent Must Have!': 10,
#  'Evies Knight. Review': 108,
#  'Exact guide': 49,
#  'Exactly what I need.': 0,
#  'Exactly what I was looking for': 36,
#  'Excelente libro de estudio!': 2,
#  'Excellent': 69,
#  'Excellent Book': 59,
#  'Excellent Source to know about Hypertension for Medics': 25,
#  'Excellent book': 80,
#  'Excellent book but it fell apart on me.': 13,
#  "Excellent book for me- I'm a bit rusty on research ...": 56,
#  'Excellent book.': 60,
#  'Excellent collection': 0,
#  'Excellent concept with one flaw': 2,
#  'Excellent text': 37,
#  'Excellent!!!': 88,
#  'Exciting': 10,
#  'Fantastic': 77,
#  'Fantastic Book!': 24,
#  'Fantastic Smithsonian Collaboration about Dinosaurs and Other Fantastic Natural Creatures': 0,
#  'Fantastic, diverse, easy to use!': 17,
#  'Fantasy-horror-rom-com with a lot of sex. A lot of fun, if you like that sort of thing.': 61,
#  'Fascinating and Refreshing Look At Jesus': 4,
#  'Fascinating!': 2,
#  'Favorite Web comic': 9,
#  'Fell in Love': 6,
#  'Fell short': 8,
#  'Fifty States: Every Question Answered': 23,
#  'Filthy Language': 26,
#  'Finances': 7,
#  'Finding birds in New Zealand d will be easier using this book.': 10,
#  'First class insight into the minds of the juvenile dispossessed.': 3,
#  'Five Stars': 52,
#  'Five Stars !!!': 0,
#  'Flash cards that give you everything you need': 4,
#  'Flashcard Fundamentals': 8,
#  'Flashcards Multistate Style': 21,
#  'Flashcards that Increase Chances of Passing': 11,
#  'For School': 8,
#  'For black belts only!': 5,
#  'For those of you who like to read a captivating mystery that also allows you ...': 114,
#  'Foreign Pharmacy in Flashcards': 8,
#  'Forensic Untrue Blue': 14,
#  'Found Something Way Better': 0,
#  'Fun book to read, a couple dated references': 25,
#  'Fun but dirty': 40,
#  'Fun on the Hersey Highway of Love': 6,
#  'Funny story and good tips': 39,
#  'Funny!!': 10,
#  'GREAT READ': 17,
#  "Gates' perspective of Obama is revealed in the Paneta/Hagel resignations": 4,
#  'Genius!!!': 27,
#  'Getting Off the Emotional Roller Coaster of Cancer is a wonderful resource not only for the cancer patient': 5,
#  'Getting to the Middle': 16,
#  'Gift for girlfriend!': 0,
#  'Give Me the World': 1,
#  'Glitter Baby is a page turner': 22,
#  'Go Jan!  Waiting for Book 2....': 27,
#  'Go with the original': 4,
#  'Good': 157,
#  'Good Book': 29,
#  'Good Message But Repetitious': 48,
#  'Good Study to You': 29,
#  'Good book': 106,
#  'Good book for a beginner.': 61,
#  'Good book, great meditation CD included': 88,
#  'Good cosy mystery': 47,
#  'Good for quick weight loss': 11,
#  'Good guide': 42,
#  'Good item': 3,
#  'Good not great': 93,
#  'Good one!': 110,
#  'Good supplement to any textbook': 3,
#  'Good textbook.': 11,
#  'Good, but is the series about to get darker?': 6,
#  'Good... but it could be better !!!': 76,
#  'Goodness': 8,
#  'Governmental Secrets in Accounting': 7,
#  'Graphic Novels and Comic Books Even an Adult Might Love': 4,
#  'Great': 6,
#  'Great Book': 68,
#  'Great Book very inspiring': 23,
#  'Great Book! Small': 75,
#  'Great Cards!!': 42,
#  'Great Characters, Excellent Story': 10,
#  'Great Lessons for Businesses, Entrepreneurs and Leaders': 13,
#  'Great Photos, Interesting Reading but Overwhelming for this Home Cook': 17,
#  'Great Picture of both old and new SBC': 0,
#  'Great Study Resource': 74,
#  'Great Travel Guide Book!': 21,
#  'Great alternative to the gym': 48,
#  'Great basic book to introduce children to heathenry': 113,
#  'Great book': 129,
#  'Great book for baking with kids!': 30,
#  'Great book for fans of Veronica Mars.': 6,
#  'Great book for the whole family': 31,
#  'Great book if you have neighbors right next to you!': 4,
#  'Great book!': 61,
#  'Great book! Great content': 115,
#  'Great cookbook!': 6,
#  'Great fit and look, but no pockets...': 0,
#  'Great for young married couples': 10,
#  'Great guide': 73,
#  'Great in-depth inductive study of the Gospel of Mark': 18,
#  'Great info': 0,
#  'Great journal': 18,
#  'Great memories!': 0,
#  'Great read': 72,
#  'Great read and truly inspirational!': 2,
#  'Great read with great info on the development of martial arts': 32,
#  'Great recipes and good stories.': 2,
#  'Great recipes and information.': 22,
#  'Great resource for everyone': 50,
#  'Great resource for software engineers and programmers learning web applications': 15,
#  'Great review book for CMA': 91,
#  'Great sense': 45,
#  'Great stories so far!': 103,
#  'Great teen fiction read. Recommended for early teens in high school': 47,
#  'Great text book': 69,
#  'Green Propaganda Targets Children': 2,
#  'Grow wise not old': 8,
#  'Gunfight: The Battle over the Right to Bear Arms in America': 0,
#  'Happy Christians': 21,
#  'Hard to get off': 0,
#  'Hard to read -': 82,
#  'Haven- the new Paranormal YA': 13,
#  'Healthy eating can be delicious!': 29,
#  'Heart touching, insightful storyline about dealing with loss': 25,
#  'Hell is the Fear of Hell': 31,
#  'Helped me out!': 5,
#  "Here's the recipes I tested and info on the special features in this cookbook. It's now a must-have for my gluten-free cooking!": 22,
#  'Hi-Ya! Test Prep': 22,
#  'Hi-larious': 66,
#  'Highly Recommend This Study Guide!': 100,
#  'Highly Recommended !!': 58,
#  'Highly Recommended !!!': 17,
#  'Highly recommended': 22,
#  'Honestly helpful. Easy to digest.': 84,
#  'Hour of the Wolf': 14,
#  'I LOVE seeing her little face light up each time she ...': 14,
#  'I LOVED IT!!': 48,
#  'I can now better educate my patients on the importance of whole foods': 38,
#  "I didn't care much for this book. Don't think ...": 23,
#  "I didn't really enjoy this book": 37,
#  'I found this to be far more fascinating than David ...': 1,
#  "I grow my own herbs year round so I'm prejudiced ...": 0,
#  "I have Unreal Engine 4 so this book didn't really ...": 52,
#  'I have both the Haynes & Chilton… for a reason.': 6,
#  'I liked it, a Little Bit, Maybe, Kinda': 68,
#  'I liked the first book more... but this was still awesome!': 23,
#  'I love it': 75,
#  "I read it before I had to and I couldn't be happier I did": 44,
#  'I really need food and water – laugh, laugh': 21,
#  'I recommend it?': 31,
#  'I truely recommend this book': 128,
#  'I was disappointed in this book': 46,
#  'I would like to believe the author': 43,
#  "Ice Dream's Wish is a book we can all learn from.": 19,
#  "If it isn't required, I wouldn't bother": 73,
#  'If you liked Wild At Heart, you will love The Heroic Path.': 4,
#  'Important Book If you are a Tesla, Space X or Elon Musk Fan': 18,
#  'In Between Days': 142,
#  'Incredibible Read!!': 14,
#  'Incredible window into the world of pop ups!!': 15,
#  'Inequality and democracy: A linkage?': 0,
#  'Informative and illuminating': 53,
#  'Informative and useful!': 72,
#  'Informative book': 2,
#  'Inner Freedom': 41,
#  "Insanity? You do know Einstein's definition of that word, right?": 32,
#  'Insightful and concise': 48,
#  'Insights Into the Man and His Methods': 3,
#  'Inspirational': 0,
#  'Inspire, Motivate, Educate': 31,
#  'Inspiring and heartfelt!': 12,
#  'Inspiring, informative, practical. An essential for anybody with ambition.': 4,
#  'Interesting perspectives': 8,
#  'Interesting triangle': 39,
#  'Interesting, Intriguing and Often Surprising': 0,
#  'Investor': 8,
#  'It all came together': 78,
#  'It explained all about the people and the way they enjoyed  life.': 58,
#  'It was a long war': 78,
#  'It was definitely different and something I would never read again or even recommend. I found myself just waiting for something': 60,
#  'It works': 0,
#  'It works!': 0,
#  'It works.': 55,
#  "It's a great adventure and a fast read": 36,
#  "It's lonely in the dark....": 3,
#  'Its all in the details........': 0,
#  "Jason's Awesome Book!": 70,
#  'Just Not Good': 69,
#  'Just ok': 1,
#  'Just what I was looking for!': 49,
#  'Justice': 4,
#  'Keep Your Family Safe!': 12,
#  'Kind of silly, but still true': 3,
#  'LOVING ARTS and CRAFTS––the Mystery/Thriller, by J.T. Prescott, of course!': 10,
#  'Large bible cover': 24,
#  'Learned some at least': 13,
#  "Let's get Technical": 42,
#  'Level 1 - Lesson Book: Piano Adventures': 1,
#  'Light, Fun Reading': 85,
#  'Like New!': 52,
#  'Looking for the cause of the sinking?': 26,
#  'Lots of information here': 19,
#  'Love it': 62,
#  'Love it!': 0,
#  'Love!': 95,
#  'Loved it': 57,
#  'Loved it!': 47,
#  'Lovely illustrations to accompany a traditional rhyme': 14,
#  'Lucado once again blows me away!': 18,
#  'MUST READ!!': 3,
#  'Made me nauseous': 7,
#  'Mail Without contents': 2,
#  'Manage your time better': 50,
#  'Material': 8,
#  'Memory Lane': 54,
#  'Mending Walls': 52,
#  'Metal Rain': 0,
#  'Mindfulness at your fingertips!': 123,
#  'More Adventures with Rose and the Tenth Doctor': 0,
#  'More Eye Candy...': 0,
#  'More please, Mr. Moore!': 40,
#  'Must Read': 17,
#  'Must have book': 42,
#  'Must have book!': 8,
#  'Must read if your a Follower of Jesus': 35,
#  'My Travel Buddy': 0,
#  "My child's favorite": 0,
#  'My first experience': 2,
#  'My girlfriend swears by them (says this is why she won).': 0,
#  'My mom reads 1 a day!': 12,
#  'My son gets lost in this book, it has ignited a love for reading for him!': 16,
#  'My son is obsessed with this book': 37,
#  'NEVER ALONE': 46,
#  'Nature Close-Up Earthworms': 3,
#  'Necessary for writers': 53,
#  'Need to switch to colored pencils for this one': 14,
#  'New Art from Old': 0,
#  'New prospective on history.': 9,
#  'Nice pictures': 8,
#  'No Way': 2,
#  'No logical flow..': 35,
#  'No more the best one in the market': 34,
#  'Nobu Vegetarian Cookbook': 2,
#  'Not For Me': 18,
#  'Not as expected': 0,
#  'Not for Me': 59,
#  'Not jumbo': 0,
#  'Notes while reading "A Death at the White Camellia Orphanage"': 2,
#  'O.K. reading': 60,
#  'Obamacare nothing but tax bill!': 29,
#  'Of interest, but nothing special': 1,
#  'Ok but can be better': 2,
#  'Okay, not great, read.': 36,
#  'Older Than I Thought': 1,
#  'Ordinary Grace': 1,
#  "Organically Yours I'm hooked": 114,
#  "Origin stories aren't always bad": 1,
#  'Out of this world': 30,
#  'Outstanding Short Stories': 0,
#  'Paleo Start': 16,
#  'Parody?': 2,
#  'Pefect for my son': 48,
#  'Perfect Companion to the HESI A2 Study Guide': 32,
#  'Perfect book for 3D printing business!': 23,
#  'Perfect book to share with your family': 69,
#  'Pertinent guidance': 1,
#  'Pocket-book': 40,
#  'Poison Study is a great beginning to the Study series': 4,
#  'Poorly written book': 12,
#  'Practical Help for Painful Trials': 10,
#  'Practical and Inspirational': 6,
#  'Practice that brings you back to the Middle': 50,
#  'Preoperative Test Prep': 30,
#  'Preoperative Test Prep in the Cards': 3,
#  'Pretty': 6,
#  'Pretty cool if you love zombies': 19,
#  'Pretty puzzle!': 1,
#  'Proceed with caution!': 15,
#  'Provides good tips!': 6,
#  'Psychic conversations. Ugh!': 22,
#  'Pure Stupidity': 16,
#  'Quick and Easy!!!': 36,
#  'Quick read and well researched...': 18,
#  'Read it, learn it, love it': 79,
#  'Really Consider this book': 118,
#  'Really Disappointing': 38,
#  'Really good for diabetics': 42,
#  'Recipes go well with my Grain Brain Book': 52,
#  'Recommend it for 10 year olds': 27,
#  'Recommend!': 8,
#  'Recommended by Bill Gates who was told to read it by Warren Buffet': 11,
#  'Recreation with Secrets': 49,
#  'Reflections on Communal Influences in Shaping the Mind': 5,
#  'Refreshing': 0,
#  'Refreshing, Honest and Encouraging-- a must read!': 22,
#  'Reused material': 67,
#  'Rocks your grill': 3,
#  'Romantic, elegant mystery': 16,
#  "Ryley's Revenge has by far be my most favorite of the Gloves Off series": 145,
#  'Saddler-esk': 0,
#  'Satisfied.': 3,
#  'Scientfic': 7,
#  'Secrets Worth Investigating': 8,
#  'Secrets for Neuroscience Nursing': 16,
#  'Secrets in Social Science': 6,
#  'Secrets to Marketing Education': 55,
#  'Security': 7,
#  'Sen. Buckley is a seer to whom we all ...': 4,
#  'Senic Driving': 1,
#  "Shoots for epic. Doesn't quite make it": 83,
#  'Shop smarter without compromising your love of fashion': 8,
#  'Skip Trace Secrets': 8,
#  'Snake bit': 88,
#  "So Many Twist & Turns You'll Be Dizzy From Them All": 22,
#  'So Very Close': 63,
#  'Solid': 31,
#  'Solid but not great.': 44,
#  'Some good info, but poorly written': 60,
#  'Somebody actually came out and said it!!!': 20,
#  'Sorce code is not available': 12,
#  'Sorry I Purchased This': 102,
#  'Sorry I bought it. Highly disappointed.': 30,
#  'Space Adventure for the X-Men': 1,
#  "Spectacular journey through Marie Antoinette's Head": 41,
#  'Stand Out Book on Narcissistic Personality': 57,
#  "Steel's - A history and a mystery": 36,
#  'Still the best guidebook to the Annapurna region': 2,
#  'Story of Love, Strength and Courage': 19,
#  'Strangely disagree': 62,
#  'Strong Willed Design for a Physical Purpose is a great book for people wanting to learn about the science ...': 8,
#  'Such a wonderful book. You should read this!': 46,
#  'Sucked me in with the first bite': 41,
#  'Suffering Well Amid the Storms': 25,
#  'Superb Read!': 37,
#  'Support and Friendship in a Book': 0,
#  'Sweet, Funny, Unexpected': 64,
#  "Take the test in advance and see how you'd do": 23,
#  'Tastey food': 29,
#  'Tells it like he saw it': 0,
#  'Thank you, thank you to the author...': 6,
#  "That second star was 'iffy'...": 3,
#  'The Age of Dead Imagination': 30,
#  'The Author Knows His Stuff': 83,
#  "The Best Yet of Child's Solo Novels!": 43,
#  'The Billionaire and The Mechanic': 5,
#  'The Catcher in the Rye': 41,
#  'The Cross of Jesus Christ is as relevant today as it has ever been, the only hope for humanity is in that triumphant Cross.': 1,
#  'The Dungeonmaster': 3,
#  'The Fast Track One-Day Detox:  Boost Metabolism, Get Rid of Fattening': 25,
#  'The Gift of Dyslexia': 11,
#  'The Tea to beat': 30,
#  'The Wandering, Wondering Mary.': 4,
#  'The best cookbook ever!': 19,
#  'The biggest waste of money and time': 16,
#  'The effect of this stuff on a once normal mind': 16,
#  'The guide is definitely worth having.': 76,
#  'The market is hot for these cards': 59,
#  'The much sought-after secret of cancer!': 35,
#  'The title of the book is not what the book is about': 0,
#  'The untold story of the birth of Bangladesh': 1,
#  'These are great for projects and the fact that they come with ...': 2,
#  'They Hate Each Other. Not!': 6,
#  'This book is amazing.': 8,
#  'This book is fun, inspiring': 25,
#  'This book is going to help in finding a cure for cancer!': 0,
#  'This book takes what could be an overwhelming process and ...': 0,
#  "This book won't help you pass..but may ensure you fail.": 5,
#  'This changed my life': 60,
#  'This guide book is PERFECT for girls!': 9,
#  'This is a must for any professional Translator or Interpreter!': 10,
#  "This reverse love story of Shakespeare's most famous play tells the story ...": 17,
#  'Thought provoking book': 2,
#  'Thought-provoking and Necessary': 34,
#  'Thoughtful examination of relationships': 0,
#  'Three Stars is Good': 78,
#  'Time and again': 1,
#  'To begin again': 21,
#  'Too complicated, lots of peppers and nightshades, and talks a lot about herself': 15,
#  'Top of the line': 43,
#  'Touching': 90,
#  'Trainspotting 28 Days Later': 30,
#  'Traveling and teaching...so rewarding and so challenging': 27,
#  'Treasured nugget': 58,
#  "Typical Rick Steves' format, but coverage is a bit thin.": 56,
#  'Unbelievable, people are praising this book when 80% of it is from Rich Dad Poor Dad': 33,
#  'Unfairly underestimated': 18,
#  'Unique, enchanting, a book to get lost in...': 5,
#  'Unusual cast of characters. Fun read.': 9,
#  'Use the guide to help you study': 42,
#  'Used not new': 0,
#  'Useless': 7,
#  'User Friendly Guide to Understanding Building Codes': 34,
#  'Utterly amazing biography': 39,
#  'Very Good Book': 84,
#  'Very cool book!': 89,
#  'Very dated classic': 75,
#  'Very easy read!': 70,
#  'Very good.': 3,
#  'Very helpful': 7,
#  'Very helpful-- we now have a much better understanding of what coaches are looking for and how ...': 64,
#  'Very informative and insightful': 12,
#  'Very informative!': 0,
#  'Very interesting, learned a ton': 94,
#  'Very solid': 10,
#  'Very well done.': 13,
#  'Very well written and educational!': 24,
#  'Vietnam and Thailand the Lonely Planet Way': 9,
#  'Was expecting more': 64,
#  'Wast of money': 5,
#  'Wasted': 77,
#  "Wasted time in my life I can't get back": 46,
#  'Way over priced!': 19,
#  'Wednesdays are for the Middle of the Week': 3,
#  'Well Written': 77,
#  "Well this was the guy's last book": 3,
#  'Well worth the investment.': 2,
#  'Well written': 70,
#  'What Is Your Score?': 0,
#  'What a Fun Read': 82,
#  'What a great read! The author paints a beautiful backdrop to ...': 2,
#  'What a wonderful learning tool': 31,
#  'What is the purpose of this creepy book?': 24,
#  'What we love and fear about the future.': 17,
#  'Who knew writing could be so fun!': 57,
#  'Whoa!': 64,
#  'Whoopie Pie Book': 24,
#  'Will Help You Get Started in Accounting': 27,
#  'Will be generous with 2 stars.': 58,
#  'Wonderful book!': 1,
#  'Wonderful books': 3,
#  'Wonderful romp in psychology and Mad Science': 8,
#  'Worth the effort': 65,
#  'Worthless.': 3,
#  'Worthy sequel': 1,
#  'Wow!': 103,
#  'Wow!  Written for an Intelligent Reader!': 107,
#  'Wow, Perfect for Couples who want their wedding to be memorable!': 4,
#  'Written for and about a teenager.....': 45,
#  'Yawn': 54,
#  'You should get it.': 28,
#  'You will WISH you read this book': 12,
#  'Youth and adults will gain much insight into solidifying their Faith': 7,
#  'a bit mature for children, and heavy on Islam indoctrination': 73,
#  "a different ride through the 60's": 25,
#  'a hoax - switch and bait': 39,
#  'a little bit "light"': 26,
#  'a must have !': 2,
#  'a must read': 3,
#  'a practical guide with lots of examples': 27,
#  'a strain to read': 63,
#  'all around cookbook and kitchen teacher': 3,
#  'and if you are mechanically driven (You work better with formulas than concepts) this book is a God ...': 0,
#  'best board books!': 62,
#  'best crystal book': 17,
#  'best for beginners': 1,
#  'board exam': 0,
#  'boring': 19,
#  'christmas present': 2,
#  'compelling': 4,
#  'concise': 59,
#  'course': 99,
#  'covered': 23,
#  'detailed': 32,
#  'details outstanding': 31,
#  "doesn't play a song, the sounds augment the story": 1,
#  "don't bother": 10,
#  'dover kicks butt': 32,
#  'dramatic page turner': 73,
#  'easy to read': 2,
#  'easy to remember': 68,
#  'easy to understand': 22,
#  'excellent !!!': 0,
#  'funny, mind boggling': 20,
#  'gift': 8,
#  'good choice': 16,
#  'good reading for adults and kids': 3,
#  'good travel guide': 2,
#  'great book': 2,
#  'great book for tractor loving kids': 1,
#  'great book great series': 124,
#  'great book!': 43,
#  'great health resource/great condition': 1,
#  'great product for 4.0': 23,
#  'great reference': 3,
#  'great resource': 20,
#  'hard to find': 0,
#  'helps with understanding the material': 42,
#  'highly recommended': 0,
#  'informative': 19,
#  'interesting': 17,
#  'is this good for diabetics': 81,
#  'it is a great learning tool for advanced economics': 4,
#  'kids love these': 81,
#  'l like the book': 0,
#  'love it': 60,
#  'mediocre': 0,
#  'mrd': 17,
#  'nice book': 29,
#  'nice edition to train old bird': 0,
#  'no': 48,
#  'no matter how smart you are': 0,
#  'not as expected': 3,
#  'not bad': 3,
#  'ok book': 52,
#  'one of my favorite areas of this country': 7,
#  'plodding and improbable': 23,
#  'poor plot,  she repeat alot of the same phrases': 11,
#  'program': 56,
#  'radi': 102,
#  'simple and clear!': 2,
#  "so assume all's good.": 0,
#  'so that just happened': 6,
#  "something's missing": 4,
#  'takes the joy away from being pregnant.': 21,
#  'terrible': 23,
#  "there are better choices I'm sure": 77,
#  'this book is almost like reading an awesome novel on the physical aspects of ...': 0,
#  'three great stores on one cd': 0,
#  'top book!': 6,
#  'typical Bourdain': 29,
#  'very informative': 35,
#  'very informative and useful': 25,
#  'we can better understand how our justice system should be designed to ...': 15,
#  'well-written and explained!': 12,
#  'wonderful': 24,
#  'wonderful crime series': 0,
#  'wow, just wow...': 11,
#  'you must read this one !': 84}
