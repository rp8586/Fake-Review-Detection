# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.read_gml('/content/ECGraphTest_0.75.gml')
nx.info(G)
# Out:
# 'Graph with 680 nodes and 12947 edges'

# %%
nx.density(G)
# Out:
# 0.05608160790089232

# %%
nx.number_connected_components(G)
# Out:
# 37

# %%
import matplotlib.pyplot as plt
import seaborn as sns
G.degree()
y= list(dict(G.degree()).values())
x=list(dict(G.degree()).keys())
plt.figure(figsize=(20,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 680 artists>

# %%
real=list(dict(G.degree()).values())
from statistics import mean
mean(real)
# Out:
# 38.07941176470588

# %%
nx.average_clustering(G)
# Out:
# 0.45854720695308504

# %%
nx.transitivity(G)
# Out:
# 0.3776561233675996

# %%
degrees = {node:val for (node, val) in G.degree()}
degrees
# Out:
# {'$200 fashion statement': 57,
#  '// Excellent audio performance, with clear, defined highs //': 35,
#  '2 in 1 ADAPTER': 8,
#  '2nd home wired!': 47,
#  '5 stars': 11,
#  '5 stars to this speaker!': 101,
#  '50% less than local supply': 6,
#  '>> Buy Only Because They Look Cool <<': 72,
#  'A Good HDMI Cable': 57,
#  'A Standard molded end cord.': 27,
#  'A bit heck yes': 67,
#  'A good product': 12,
#  'A great HDMI cable': 35,
#  'A little flimsy': 27,
#  'A must be item': 92,
#  'A must for the Master bedroom': 53,
#  'A must have!': 57,
#  'A versatile, one-stop power strip for most any task': 1,
#  'AM/FM Walkman': 4,
#  'AMAZE-BALLS!': 41,
#  'AMAZING speaker': 12,
#  'Absolutly Useless': 7,
#  'Affordable, versatile': 60,
#  'Amazing': 21,
#  'Amazing Charger. Almost everything!!!': 64,
#  'Amazing Little Bluetooth Speaker! Sound Really Packs a Punch': 89,
#  'Amusing': 4,
#  'An incredible bargain, once initial problems were solved': 8,
#  'Annoying hissing': 127,
#  'Apple iPod touch 8 GB Black (4th Generation)': 3,
#  'As expected of case logic, this one is really ...': 45,
#  'Average product no bad not so good': 9,
#  'Awesome': 102,
#  'Awesome antenna..': 6,
#  'Awesome for my 2 year old & would easily fit up to 6 year old too.': 9,
#  'Awesome seller!': 14,
#  'Awesome speaker': 32,
#  'Awesome!': 1,
#  'Awesome!!': 5,
#  'Bad , Zero stars !': 23,
#  'Bargain king.': 65,
#  'Beats': 43,
#  'Beautiful lookin and sounding': 11,
#  'Below average sound': 28,
#  'Best Voltage Converter Transformer': 1,
#  'Best headphones on the market': 54,
#  'Best iPhone to date': 24,
#  'Best invention EVER for swimming!!!': 28,
#  'Best value i could find': 82,
#  'Best wireless out there': 75,
#  'Better than Scosche': 0,
#  'Big clunking noise - then silence': 4,
#  'Big sound, not too much money': 21,
#  'BlueRigger HDMI cable': 42,
#  'BlueRigger High Speed Micro Cable': 3,
#  'Bought these to go with the hammock we bought to help us install it to the posts on our porch': 6,
#  'Breaks HDCP, HDMI Audio issue': 66,
#  'Bright Blue Without the Blues': 81,
#  'Broke 2 times in a row': 25,
#  'Broke after a week': 135,
#  'Built tough': 13,
#  'But the sound of a large performance is not bad.': 3,
#  'Camping perfection!': 21,
#  'Can not say enough great things about this mount': 50,
#  "Can't keep track of distance for running": 2,
#  "Can't set the alarm or the clock": 32,
#  'Channels': 4,
#  'Classy Headphone Display': 97,
#  'Close but not quite perfect': 58,
#  'Combine very good audio quality and comfortable design': 126,
#  'Comes In Very Useful For Surround Sound Systems': 8,
#  'Comes with issues': 12,
#  'Comfortable, & they stay where you put them!': 7,
#  'Crank wont turn': 57,
#  'Crappy sound': 16,
#  'DO NOT BUY!!! WASTE OF MONEY!!! DOES NOT LAST!': 85,
#  'DSS922 DSS Dual LNBF  Buyer beware. Rude customer service representatives. Va surplus  Find another seller!': 0,
#  'Daughter loves these!': 8,
#  'Debatable quality': 26,
#  'Debbie Gibson Approved!!': 0,
#  'Decent and effective brackets for sound bar': 33,
#  'Decent batteries': 72,
#  'Decent for the price.': 45,
#  'Decent piece of equipment': 75,
#  'Decent, you get what you pay for...': 0,
#  'Definitely High Quality HDMI': 83,
#  'Definitely recommend': 19,
#  'Delivers as promised': 67,
#  'Despite the different size ear pieces poor fit into ears': 13,
#  "Didn't meet up to my expectations": 87,
#  'Didnt work': 15,
#  'Died': 14,
#  'Disappointed': 39,
#  'Disappointed, really': 14,
#  'Disappointing performance': 16,
#  'Distortion': 10,
#  'Do I need to say anymore?  Haha': 120,
#  'Do not hesitate, it is super.': 46,
#  'Do not work well with all devices': 18,
#  'Does NOT work with Asus BW-12B1ST': 44,
#  'Does not recharge': 23,
#  'Does not work with iPhone 5': 69,
#  'Does what it should': 145,
#  "Doesn't give off the nice, full sound that i would have wanted for ...": 8,
#  "Doesn't hold accurate time": 45,
#  'Doesn`t work for me': 147,
#  "Don't Buy!": 18,
#  "Don't be hard on them": 65,
#  "Don't buy the white!": 17,
#  'Dropouts': 30,
#  'Drops signal': 21,
#  'Drown things out': 1,
#  'Durable, I like it.': 62,
#  'EASY to set up & picks up 78 digital channels for my Sony Bravia EX710 tv': 29,
#  'Easy to Install & Use': 79,
#  'Easy to connect': 41,
#  'Easy to install': 24,
#  'Easy to mount': 12,
#  'Easy way to make the television look new.': 20,
#  'Exactly what I was looking for!': 33,
#  "Exactly what it's for.": 34,
#  'Exactly what my wife wanted. It replaced one that ...': 19,
#  'Excellent': 5,
#  'Excellent Cord': 30,
#  'Excellent Product': 16,
#  'Excellent Remote': 5,
#  'Excellent Sound': 53,
#  'Excellent casque': 0,
#  'Excellent for Bookshelf speakers': 27,
#  'Excellent value': 62,
#  'Excellent value and rechargeable!': 85,
#  'Excellent wireless range': 68,
#  'Excellent!': 18,
#  'Expensive and mostly worth it': 14,
#  'FIVE STARS PLUS !!!': 107,
#  'Fair Sound, Risky Business': 65,
#  'Fair, battery charge not good': 24,
#  'Fantastic': 29,
#  'Fantastic Remote': 45,
#  'Fantastic Remote Control...!!!': 19,
#  'Fantastic batteries.': 26,
#  'Fantastic bluetooth waterproof shower speaker! we use it daily!': 65,
#  'Fantastic ear phones!': 168,
#  'Fantastic feature': 7,
#  'Fantastic!': 22,
#  'Fast & Great system': 11,
#  'Favorite style of surge protector': 14,
#  'Feet are too big and not worth it, even at the price.': 11,
#  'Finally - a universal remote that actually works!! WTG Logitech': 22,
#  'Finally one that does not compromise volume': 23,
#  'Finally thinking outside the box': 76,
#  'Fine but not a heavy cable.': 16,
#  'First over the ear headphones!': 52,
#  'Fit Perfectly and Works Great': 51,
#  'Fit and sound quality is excellent!': 60,
#  'Five Stars': 55,
#  'Flexible': 15,
#  'Four Stars': 3,
#  'Functional and cost-effective adapters': 54,
#  'Gaming heaven': 9,
#  'Georgious flop': 53,
#  'Get every channel now. Had a loop antenna with ...': 21,
#  'Good Cable adapter for Nexus 5': 10,
#  'Good Headphones Especially for the Price': 55,
#  'Good Inexpensive Optical Cable - Works as Advertised': 144,
#  'Good antenna instead of cable TV': 22,
#  'Good batteries': 53,
#  'Good buy': 44,
#  'Good enough alarm clock.': 8,
#  'Good headphones, but careful of the hinges.': 5,
#  'Good iphone radio and good price': 58,
#  'Good player at a decent budget': 14,
#  'Good product': 52,
#  'Good product!': 53,
#  'Good product, lower side of life cycle': 21,
#  'Good quality': 14,
#  'Good so far': 4,
#  'Good sound quality': 23,
#  'Good sound, a bit muffled. Build quality was horrible.': 43,
#  'Good sound, great value, but connectivity not quite as good as other devices': 94,
#  'Good sound, nice carrying case': 62,
#  'Good surge protector for elliptical.': 6,
#  'Good value 5 port HDMI Swtcher. Includes the power supply.': 32,
#  'Good value; feels a little cheap': 112,
#  'Good,no.....Its Great!': 47,
#  'Good.': 11,
#  'Great': 60,
#  'Great Battery': 3,
#  'Great Build for the Price': 37,
#  'Great Buy': 27,
#  'Great Cable Great Price': 40,
#  'Great Deal': 31,
#  'Great Disks': 0,
#  'Great HDMI cable': 54,
#  'Great Headphone': 2,
#  'Great Headphones!': 77,
#  'Great Product': 57,
#  'Great Service': 21,
#  'Great Sound': 70,
#  'Great Sound and Very Comfortable': 45,
#  'Great Sound, Great price.': 58,
#  'Great Sounds': 33,
#  'Great Speaker!': 17,
#  'Great UHF antenna!  - But will not receive the lower VHF-High stations!': 48,
#  'Great amp': 9,
#  'Great antenna for the $': 46,
#  'Great batteries with one small warning': 73,
#  'Great batteries!': 48,
#  'Great batteries. Lasts longer than standard, and reduces waste.': 20,
#  'Great buy and it works with clear HD quality.': 35,
#  'Great buy for cost, style, and sound! GET THEM!': 39,
#  'Great classroom speaker.': 1,
#  'Great coupler!!': 27,
#  'Great device for Bluetooth audio!': 75,
#  'Great earphone': 13,
#  'Great fit': 31,
#  'Great for audio recording': 41,
#  'Great for kids and wife even uses!': 3,
#  "Great for surges but doesn't stay on long": 11,
#  'Great gift idea': 100,
#  'Great gift option': 6,
#  'Great iPhone 5 dock clock!': 48,
#  "Great integrated amplifier, and huge value!  Get a good pair of speakers and you're 'all set'!": 42,
#  'Great little hand-sized speaker.': 1,
#  'Great looks and fit; as durable as the original': 114,
#  'Great product': 12,
#  'Great product - great price!': 149,
#  'Great product at a great price!': 29,
#  'Great product. Bad shipping box.': 6,
#  'Great purchase!': 42,
#  'Great quality for the price': 14,
#  'Great reception': 0,
#  'Great short cables': 78,
#  'Great sound from such a small package.': 34,
#  'Great sound from this Bluetooth-enabled speaker!!!!': 67,
#  'Great sound quality': 197,
#  'Great sound, Great volume': 64,
#  'Great unit, great price': 36,
#  "Great we'll made headphones": 13,
#  'Great work': 12,
#  'Great!': 68,
#  'HEADPHONES FOR WORK': 79,
#  'Hands down, if you have $200-500, look at this and no other.': 2,
#  'Happy to purchase': 0,
#  'Happy with my choice': 75,
#  'Happy, happy, happy!': 51,
#  'Has a great osund': 65,
#  'Headset splitter': 26,
#  'Hey!': 0,
#  'High quality': 63,
#  'Highest recommendation !!': 12,
#  'Highly recomended product.': 107,
#  'Hissing': 37,
#  'HomePlug capable extension plug': 41,
#  'Horrible': 0,
#  'I absolutely love this speaker, and the SONOS system.': 36,
#  'I am glad': 33,
#  'I am so happy with the opportunity to evaluate these in ear earbuds ...': 89,
#  "I couldn't get signals before on my TV, now I can, digital and analog": 59,
#  'I like this speaker very much': 0,
#  'I live in a metro area with a clear line ...': 11,
#  'I love it': 37,
#  "I love it. It's just what they say it is": 1,
#  'I love just plugging my USB into the front': 90,
#  'I love my Bose': 0,
#  'I love these headphones!I like the design as well.': 145,
#  'I now have smart speakers': 75,
#  'I paid a good price and got exactly what I was expecting and ...': 17,
#  'I prefer PowerSonic brand batteries': 66,
#  'I previously used and loved a set of sony ones but they were discontinued': 92,
#  'I really love these!': 110,
#  'I tend to really like Amazon Basic products - they get the job done ...': 90,
#  "I upgraded my HTCT100 and couldn't be happier - expansive sound, easy setup, and great price - Bluetooth a major bonus as well": 30,
#  'I was a pretty committed SkullCandy user': 74,
#  "I wasn't sure how I would like the protrusion in my ear": 26,
#  'I will recommend it to people who buy this product': 1,
#  'I would recommend this to anyone needing to replace their LNB on ...': 0,
#  "I'm glad I got the three pack": 16,
#  "I'm pleased with the performance of this product": 97,
#  "I'm still amazed at the quality of these cables for the price": 40,
#  'IT SUCKS! DIDNT EVEN LAST A YEAR!': 25,
#  'Ideal': 2,
#  "If you don't mind wrinkles......": 52,
#  'Impressive': 112,
#  'Incredibly awesome': 50,
#  'Indeed a "perfect replacement" for our old Philips-Magnavox TV, ...': 2,
#  'Interfers with WIFI!': 118,
#  'Interfers with my WiFi': 24,
#  'It Works': 1,
#  'It is a nice radio but I have trouble setting it up the ...': 11,
#  'It now resides in the local garbage dump!': 56,
#  'It works': 103,
#  'It works-- just not the way I expected': 43,
#  'It works.': 6,
#  "It's HUGE that's why it's perfect": 18,
#  "It's OK": 7,
#  "It's always boomin' in my house": 145,
#  "It's good": 17,
#  "It's good for its price": 29,
#  "It's good wire...": 0,
#  "It's loud, clear. Sound don't get distorted. ...": 4,
#  "It's ok for the price, but you need to know what your doing": 8,
#  "It's ok, but...": 17,
#  'Its a good product that does its job well': 85,
#  'Its of a Good value': 11,
#  'JBL Micro Wireless Speaker': 87,
#  'Just as advertised': 72,
#  "Just don't work": 13,
#  'Just what I needed': 4,
#  'Keeps consoles out of the way': 4,
#  'Kobo No': 62,
#  'LOVE IT!': 33,
#  'Left earbud no sound': 3,
#  'Less than half the price of the APC battery and it works': 2,
#  'Lets me use my surface pro on the big screen!': 16,
#  'Light weight and great sounding.': 18,
#  'Lightening fast service': 7,
#  'Limitations of Projection and Radio Reception Quality': 5,
#  'Listen To TV At Your Own Volume': 29,
#  'Listening made simple': 64,
#  'Little disappointed.': 16,
#  'Little unit, big sound': 0,
#  'Looks good - works good': 52,
#  'Looks good, hides wires, sturdy': 35,
#  'Looovvveee': 54,
#  'Love it': 33,
#  'Love these': 63,
#  'Love these headphones': 36,
#  'Love these speakers even 3 years later!': 59,
#  'Love these!': 107,
#  'Love this item.': 64,
#  'Love this little device': 13,
#  'Loved it': 15,
#  'Loved it!': 128,
#  'Lovely ear-phones': 146,
#  'Loving it!': 112,
#  'Loving the sound and a great deal!': 57,
#  'Matches my hair!': 13,
#  'Maxell dry video head cleaner': 17,
#  'Meets the need better than the others': 74,
#  'Meh': 49,
#  'Memories.': 18,
#  'Mixed results': 2,
#  'Monitor was not able to recognize it': 32,
#  'Most Useful Travel Charger': 55,
#  'Mostly fine': 2,
#  'Music coming from this little speaker sounds terrific! This baseball -like speaker comes with a small USB to USB-mini cable for': 35,
#  "My office at work has a nice professional phone system with a wireless headset so I can type while I'm on calls. Things are a li": 18,
#  'NOT A CYBERPOWER RB1280X2D REPLACEMENT BATTERY': 4,
#  'NOT A CYBERPOWER REPLACEMENT BATTERY': 4,
#  'NOT for an iPhone with a cover like mine': 13,
#  'Never leave home without it': 0,
#  'Nice': 53,
#  'Nice 5 star mount!': 26,
#  'Nice Projector': 21,
#  'Nice Sound': 186,
#  'Nice and light': 13,
#  'Nice cables': 98,
#  'Nice glasses': 45,
#  'Nice headphones for the price': 62,
#  'Nice headsets with this price': 103,
#  'Nice idea with a good sound': 78,
#  'Nice item for the price': 23,
#  'Nice product great price': 65,
#  'Nice quality cable.': 14,
#  'Nifty Little Device from Harmon Kardon': 38,
#  'Nifty and practical little speaker with nice sound': 35,
#  "Nightmare system... Don't buy!": 33,
#  'No more worrying I left my devices plugged': 46,
#  'No reason to pay more.': 15,
#  'Not Working!': 14,
#  'Not a quality stereo': 7,
#  'Not bad': 100,
#  'Not bad but not great either': 53,
#  'Not bad but rather overpriced': 105,
#  'Not good': 12,
#  'Not happy': 18,
#  'Not necessary to buy APC brand batteries': 5,
#  'Not recommended.': 27,
#  'Not the best': 6,
#  'Not the same software as the previous PE mp5 players': 82,
#  'Not what I wanted': 19,
#  'OK for speaker / sub': 56,
#  'OK for the money': 16,
#  'Okay': 49,
#  'Only faint audio': 51,
#  'Only very slight signal improvement - not worth it - returning': 66,
#  'Opinion from a user of many headphones including other JVC headphones': 2,
#  'Outstanding headset.': 37,
#  'Over the ear headset': 23,
#  "Overall it's Good!": 2,
#  'Overpriced for what it does': 60,
#  'PERFECTION!': 26,
#  'Pal TV for ABS-D flight reception': 0,
#  'Paying for name': 51,
#  'Perfect Remote': 44,
#  'Perfect bass enhancement for the audio technica ath-m50x': 94,
#  'Perfect for my mini bose headphones': 45,
#  'Perfect for rear home theater speakers': 60,
#  'Perfect for the Price': 40,
#  'Perfects syncs my MacBook Pro with my new non Mac monitor': 109,
#  'Performance Value Trade off': 24,
#  'Philips Tread Earbud': 40,
#  'Plenty of room for my remotes,needs a carrying handle.': 25,
#  'Plug and Play': 43,
#  'Poor sound': 58,
#  'Possible inexpensive fix for legacy monitors': 0,
#  'Premium 16/2 Awg 100 Feet CL2 Speaker Wire Cable - Oxygen Free Copper': 14,
#  'Pretty good headphones': 67,
#  'Pretty good noise': 27,
#  'Price is right!': 74,
#  'Problems with WiFi': 33,
#  'Product did not come as pictured': 18,
#  'Purchase ok but not to my liking': 30,
#  'Quality is very good': 53,
#  'Question': 0,
#  'Quick and easy!': 33,
#  'Quite Sturdy': 11,
#  'Quite good...!!': 71,
#  'RECOMMENDED': 30,
#  'Radio stations come in pretty clear. I think this s great radio for ...': 24,
#  'Read the details carefully': 0,
#  'Real quick and to the point - Sounds is clear ...': 19,
#  'Really amazing': 17,
#  'Really cool': 22,
#  'Recommended': 0,
#  'Recommended!': 0,
#  'Reliable': 30,
#  'Remarkably Good Sangean CL-100 Weather Radio': 38,
#  'Replaced an old boombox on the porch': 3,
#  'Replacement Transformer': 21,
#  'Right on time': 6,
#  'Rusted grill': 0,
#  'STR-DN1030 Review': 5,
#  'San Disk Sansa clip': 2,
#  'Screen is very bright': 7,
#  'Seriously?': 3,
#  'Serviceable but Very Proficient Customer Service!': 52,
#  'Should have known better. Good buy': 7,
#  'Should of bought one of these long ago.': 7,
#  'Should of bought this before great sound quality rated': 89,
#  'Signal breaks up': 3,
#  'Signal drops out': 11,
#  'Similar problem to earlier reviewer. The control triggered the ...': 1,
#  'Simple, simple, simple.': 74,
#  'Sleek and light': 46,
#  'So cheap!': 38,
#  'So good as a gift.': 104,
#  'So much better than using batteries.': 4,
#  'So small but so big.': 12,
#  'So sweet I love it': 75,
#  'So-so reception': 23,
#  'Solid Stands - very cool...': 5,
#  'Solid buy Good for the Price range': 14,
#  'Solid cables': 101,
#  'Solid stands for the price': 8,
#  'Sony 950 Series': 7,
#  'Sound Tower Review': 7,
#  'Sounds great for the small size': 40,
#  'Sounds great!': 31,
#  'Speaker works fine, but the stick on tape used for the ...': 5,
#  'Spin Clean system': 56,
#  'Static': 3,
#  'Steren 251-152 S-Video To RCA Adapter - S-Video M To RCA F': 0,
#  'Storage case got to me within good time. Very happy with this purchase as I ...': 66,
#  'Super Cheap': 14,
#  'Superb quality and close to the originals ones': 102,
#  'Symphonized NRG Premium Genuine Wood In-ear...': 17,
#  'TERRIBLE!!': 48,
#  'THESE ARE THE BEST!': 6,
#  'TV cabinet': 1,
#  'Takes some getting used to': 6,
#  'Thank you Westone!!!!': 75,
#  'The best!': 26,
#  'The box is sturdy and it looks handsome as well': 1,
#  'The included anchors worked great for brick installation': 27,
#  'The quality is good and the price is great': 27,
#  'The ties work great for what they are and I have had no ...': 24,
#  'These are decent headphones for the price, definitely not ...': 94,
#  'These are great and would buy them again': 23,
#  'These buds be JAMMIN': 43,
#  'These headphones are great to work out with': 47,
#  'These headphones sound good, are comfortable': 64,
#  'These speakers are great!': 1,
#  'These thing are great for the price': 28,
#  'They are much better sounding than I expected for the price and the ...': 69,
#  'They love them and so do their friends': 12,
#  'They usually work': 11,
#  'They work are nice and thick.  No problems with these at all.': 70,
#  'This Power center sucks. I had it connected to my 4k TV ...': 18,
#  'This camera is the best available. Camera picture was amazing during the day': 18,
#  'This dock rocks!': 38,
#  'This is a good sounding bookshelf speaker': 22,
#  'This is a great addition to my Surface Pro 3.': 23,
#  'This is a quality product!': 7,
#  'This is an awsome solution for 9V NIMH batteries': 54,
#  'This is my favorite thing!': 53,
#  'This is the third sansa clip I own I love it, as far as quality it beats all ...': 98,
#  'This sounds just as good and much better price': 12,
#  'Too bad I found out after I had bought it': 7,
#  'Top-notch Toslink (Audio) Cables': 123,
#  'Tried several other devices': 4,
#  'Universal remote for Roku 3': 5,
#  'Unknown brand = get what you pay for': 49,
#  'Useful': 5,
#  'Value!': 60,
#  'Very Satisfied': 48,
#  'Very cool': 60,
#  'Very cool looking, mixed features': 55,
#  'Very durable and soft, 5 year old daughter loves them': 9,
#  'Very functional': 26,
#  'Very good': 22,
#  'Very good for troubled sleepers': 10,
#  'Very handy batteries!': 104,
#  'Very happy with this product': 29,
#  'Very simple to hang on wall': 19,
#  'VvW RRLM2596 Adjustable 4.0-40V to 1.25-37V 5/12V DC Voltage Regulator Experimental Power Buck Converter with LED Voltmeter': 10,
#  'WAS happy with it!': 37,
#  'WASTE OF MONEY!!! Low quality and not comfortable AT ALL!!!': 38,
#  'WORKED LIKE A CHARM!!': 6,
#  'Waste of money': 35,
#  'We finally can use all the features on our BluRay again!': 44,
#  'Well package for good quality': 76,
#  'What I Think': 47,
#  'What a disappointing product': 119,
#  'What a great deal!': 52,
#  'What???': 3,
#  'When you think China; Think... BUYER BEWARE!': 39,
#  'Wonderful': 116,
#  'Wonderful speakers': 66,
#  'Work great for on the go.': 73,
#  'Work well...': 19,
#  'Worked Great.': 0,
#  'Worked great': 4,
#  'Worked great for a couple months then.....': 74,
#  'Working affordable Europe to USA adapter': 25,
#  'Working flawlesly': 43,
#  'Works Great! (*Update!)': 91,
#  'Works Just Like Advertised': 56,
#  'Works as advertised': 121,
#  'Works as advertised could save your life .': 1,
#  'Works as advertised no complaints': 16,
#  'Works as expected': 3,
#  'Works great': 0,
#  "Works great BUT you'll need a strong cat5.  Otherwise you might have annoying issues.": 4,
#  'Works great for me.  Love the small size and modern look.': 21,
#  'Works great with CDR/MP3 files': 13,
#  'Works great--free TV once again.': 34,
#  'Works perfectly': 2,
#  'Works pretty good': 40,
#  'Works really good the sound is amazing good quatily': 2,
#  'Works well': 25,
#  'Works well...': 49,
#  'Works!': 80,
#  'Worthless for 3D. Ok as sun glasses.': 24,
#  'Would definitely recommend it!': 77,
#  'Would not hesitate to recommend': 1,
#  "Wouldn't waste the money twice!": 100,
#  'Wuz great at first, nao it is not as great... T_T': 3,
#  "XPand G;asses Don't Work w/ LG Plasma": 39,
#  'You be da boss.': 22,
#  'You will love them': 136,
#  "You'll be happy you checked ou these headphones! Great Build and Looks...": 26,
#  "You're the best.": 11,
#  'Your experience may vary': 3,
#  'a great purchase.': 28,
#  'adaptor': 0,
#  'after 45 minutes on this system, I threw it ...': 25,
#  'amazing battery': 23,
#  'as advertised': 3,
#  'awesome': 101,
#  'awesome upon arrival....': 8,
#  'bad charger..': 9,
#  'bad picture quality': 56,
#  "bangin' for the price. recommended!": 48,
#  'battery very fast': 45,
#  'best bass': 47,
#  "best ear bud head set I've ever used": 40,
#  'best quality': 26,
#  'bought 2 both broke the same way': 0,
#  'bought this for the in laws. they use European ...': 0,
#  'bright and perfect': 5,
#  'buy.buy.buy!!!!': 48,
#  'buying an hdmi wire': 1,
#  'cheap product': 66,
#  'cheaply made': 63,
#  "comfortable but sound's horrible": 60,
#  'cool headset, and 5 stars for 3 set of inexpensive headset covers.': 0,
#  'disappointed to say the least': 11,
#  "doesn't work": 12,
#  'earphone': 53,
#  'excellent': 28,
#  'functions very well': 25,
#  'get it': 17,
#  'getting what you paid for is only fair': 9,
#  'good but not loud enough': 28,
#  'good for the price': 1,
#  'good purchase': 85,
#  'good size which makes it easy storing': 27,
#  'good subwoofers': 24,
#  'good value': 8,
#  'great 3D': 106,
#  'great buy happy': 115,
#  'great for comfort, sound and price': 118,
#  'great for working out': 52,
#  'great player': 38,
#  'great product': 101,
#  'great product for emergencies': 10,
#  'great value, comfortable': 81,
#  'handiest things ever in the office': 0,
#  'hanging 46"': 7,
#  'headphone w/ neckband YAY': 53,
#  'heavy Wall Mount': 35,
#  'hide-a-speaker for best results!': 19,
#  'high quality  hdmi cable': 35,
#  'i had it replaced once since the aux input broke ...': 27,
#  'i love this so much': 41,
#  'i only can take out let it become cool then i use it again': 29,
#  'it has gotten worse': 49,
#  'it hissed and popped.': 39,
#  'it looks beautiful but it is just a junk,only worked for about 1.5 weeks,then it can not work any more,': 8,
#  'its a great deal. We have 3 of them for our ...': 5,
#  'jillo': 16,
#  'just great': 23,
#  'just not work and receive fewer channel also the quality is bad, I am not sure I got lemon but ...': 29,
#  'like it': 87,
#  'like the original': 0,
#  "little hamburger shaped speaker works better than any larger speaker I've had": 5,
#  'love these things': 81,
#  'lovely headphone for music lover': 103,
#  'loves them!': 61,
#  'more than what I expected!': 115,
#  'much better': 60,
#  'must be broken in': 103,
#  'my new earbuds': 1,
#  'my son can now listen to music even from his bedroom': 31,
#  'nice': 28,
#  'nice power strip': 0,
#  'no surprises, it is a factory remote control': 19,
#  'not bad': 42,
#  'not in-wall...': 24,
#  'not play.': 49,
#  'not super bass': 18,
#  'okay this speaker is pretty great but it took me a while to figure ...': 33,
#  'perfect!': 17,
#  'poor quality': 8,
#  'portable player': 10,
#  'pretty good': 132,
#  'quick charger and lasting battery': 12,
#  'radio wakeup': 97,
#  'rip off': 8,
#  'satisfied': 68,
#  'screen frozen': 23,
#  'sharp picture': 87,
#  'shattered upon delivery': 2,
#  'simply fantastic': 97,
#  'so I looked at this and I was already amazed by what it is': 55,
#  'so so': 6,
#  'son loved it': 17,
#  'sounds quality is very low': 22,
#  'space manager in the house.': 10,
#  'speaker review': 45,
#  'the exact original quality replacement.': 2,
#  'they still sounded really good! The quality of the sound is crisp and ...': 21,
#  'they work great. Easy set up': 36,
#  'this invention is very useful. What port should you pick its your choise': 6,
#  'this is awesome remote': 11,
#  'this is the best headphone I bought for my son it durable and ...': 49,
#  'this product works great and I love being able to charge multiple devices': 37,
#  'too big': 0,
#  'unclear instructions.': 16,
#  'updated transistor radio!': 2,
#  'use for hands-free not music': 138,
#  'user friendly': 26,
#  'very good product make quality and sound quality is amazing': 34,
#  'very poor quality, so many reviews are cheat customer': 58,
#  'well satisfied by the good work it does': 58,
#  'works as expected': 0,
#  'worth for its price': 59,
#  'worth for money': 86}
