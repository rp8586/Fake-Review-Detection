# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.read_gml('/content/GCGraphTest_0.75.gml')
nx.info(G)
# Out:
# 'Graph with 683 nodes and 25876 edges'

# %%
nx.density(G)
# Out:
# 0.11110204677483759

# %%
nx.number_connected_components(G)
# Out:
# 19

# %%
import matplotlib.pyplot as plt
import seaborn as sns
G.degree()
y= list(dict(G.degree()).values())
x=list(dict(G.degree()).keys())
plt.figure(figsize=(20,5))
plt.bar(x,y)
# Out:
# <BarContainer object of 683 artists>

# %%
real=list(dict(G.degree()).values())
from statistics import mean
mean(real)
# Out:
# 75.77159590043924

# %%
nx.average_clustering(G)
# Out:
# 0.5282862563442542

# %%
nx.transitivity(G)
# Out:
# 0.4683309101071526

# %%
degrees = {node:val for (node, val) in G.degree()}
degrees
# Out:
# {'*Best persian saffron*': 57,
#  '36.99?  The price is very high.': 52,
#  '5 Stars': 218,
#  'A Little Light on Flavor, Too Heavy in Sodium ...': 148,
#  'A Must Have': 3,
#  'A Real Sweet Deal': 238,
#  'A bit pricey here': 179,
#  'A can of refried beans': 17,
#  'A delicious and flavorful black tea': 109,
#  'A delightful (??) hot sauce': 34,
#  'A drink that nutritionally replaces a meal and tastes awesome!': 202,
#  'A family favorite': 111,
#  'A fun time!': 19,
#  'A good product nevertheless': 49,
#  'A great disappointment': 154,
#  'A great product!': 166,
#  'A holiday favorite': 60,
#  'A little goes a L O N G ways': 196,
#  'A mixed bag': 122,
#  'A terrific taste': 146,
#  'A very good buy!': 177,
#  'AMAZING FLAVOR': 131,
#  'AS expected': 0,
#  'Addicted!': 181,
#  'Addictive sea salt': 33,
#  'Affordable goat milk!': 70,
#  'All bold, no bite': 75,
#  'All good': 21,
#  'Altoids Smalls': 87,
#  'Amazing Mayo, Just so-so muffins.': 236,
#  'Amazing Sea Salt': 17,
#  'An acquired taste.': 64,
#  'An organic SCAM! matchaDNA is NOT CERTIFIED ORGANIC!': 1,
#  'An unusually awesome popcorn!': 61,
#  "Andria's Brush-on Steak Sauce Is More Like A Soy Sauce Gravy.": 13,
#  'Apparently it is all hype': 11,
#  'Arrived melted': 1,
#  'As good as it was': 13,
#  'As long as I can get Don Pablo I will ...': 0,
#  'Awesome Imperial Stout': 126,
#  'Awesome Product': 156,
#  'Awesome seasoning!': 75,
#  'BEST DETOX EVER!!!! DELICIOUS!!!!!': 223,
#  'BEST YEAST IN THE WEST OR EAST OR INBETWEEN': 29,
#  'BEST fruitcake ever!!!': 66,
#  'BEWARE of LEAD CONTAMINATION IN CHINESE MATCHA!!!': 8,
#  'BEWARE of the DANGER of LEAD CONTAMINATION in CHINESE MATCHA!!!': 6,
#  'BYE BYE RED BULL AND MONSTER HELLO BHIP': 45,
#  'Bad but': 20,
#  'Bad product! NOT recommeded!!!': 5,
#  'Bag the bags and go loose': 43,
#  'Best': 5,
#  'Best Coffee Ever': 117,
#  "Best English Muffin I've ever had (and that goes for the wheat based ones, too) ...": 268,
#  'Best Gluten Free mix ever!': 152,
#  'Best K Cup': 57,
#  'Best Organic Alfalfa Seeds Around!': 25,
#  'Best Tasting Stevia!!': 122,
#  'Best brand': 27,
#  'Best coffee': 146,
#  'Best curry': 26,
#  'Best granola ever!': 63,
#  'Best oil': 8,
#  'Best tasting K-Cup coffee': 15,
#  'Big babies': 0,
#  'Bigelow Teas': 36,
#  'Blue Monkey is the best BUT the quality of the product here is terrible': 59,
#  'Blues are the best!': 1,
#  'Brachs Jelly Nougats candy': 61,
#  'Bread is good by not much of a rye taste': 3,
#  'Broken cookies when opened :(': 78,
#  'Buy the Ekobrew instead': 154,
#  'Buyer beware - pricing out of line': 76,
#  'Buyer beware...': 6,
#  'By Far my best Herbal Tea Blend': 129,
#  'CAN NOT beat the price!': 64,
#  'Caffeine Free Tea': 58,
#  'Cajun boiled peanuts nice and easy': 44,
#  'Can it really be light?': 239,
#  'Chai with no cream or sweetener....': 179,
#  'Changed the formula!': 63,
#  'Chia seeds are awesome': 122,
#  'Childhood Memories': 92,
#  'Chinese Matcha may be unhealthy due to high levels of heavy metal lead!!!': 16,
#  'Chips great. Tasted Good!': 1,
#  'Chocolate Pez!': 27,
#  'Cinnamon Roll K-cups': 103,
#  'Consistent': 147,
#  'Contains Corn Syrup': 135,
#  'Convenient and Healthy': 13,
#  'Convienant Packaging, delicious taste': 134,
#  "Cracker Jack'D Snack Mix": 38,
#  'Crazy delicious stuff!': 71,
#  'Creamy and Crunchy': 134,
#  'Crispy White Jolly Time is Great': 5,
#  'Cup container is handy for snacking while driving': 93,
#  'DEEELLIICCIIOUSSSS': 153,
#  'DELICIUOS !!!': 87,
#  'DO NOT BUY': 11,
#  'DRY BUT NOT TOO GOOD': 6,
#  'DaMatcha took me back to Japan!': 7,
#  'Definitely not my favorite. It smells and tastes like grass and it ...': 82,
#  'Delicious': 35,
#  'Delicious Coffee': 23,
#  'Delicious and Nutritious!': 70,
#  'Delicious and VERY dark': 11,
#  'Delicious but a bit expensive': 157,
#  'Delicious but could be less expensive elsewhere': 80,
#  'Delicious however Jovial brand is better in quality': 56,
#  'Delicious!!': 0,
#  'Delicious... Warning: Be prepared to run ...': 0,
#  'Delicious...delicious....delicious.': 1,
#  'Deliciousness by the gallon': 108,
#  'Delightfully Smooth Moisturizer': 58,
#  'Dented cans!': 17,
#  'Did not do well in the shipping process': 13,
#  'Did not receive the size I ordered.': 115,
#  'Didnt really care for': 46,
#  'Different, But Delicious': 41,
#  'Don"t Let the Cheaper Price Fool You': 41,
#  'Dont drink and shop!': 2,
#  'Dried fruit candy nut tray': 0,
#  "Duke's mayonnaise, tangy, sugar free": 153,
#  'Easy to flavor up your popcorn a little or a lot': 156,
#  'Easy to use and tastes great': 43,
#  'Economical beans': 81,
#  'Edamame, Wasabi Green Soybeans, Spicy': 90,
#  'Energetically high coffee beans.': 45,
#  "Everybody Loves 'em": 11,
#  'Excellent': 49,
#  'Excellent - so smooth - so tasty and loaded with chips also': 17,
#  'Excellent Coffee!': 237,
#  'Excellent Olive Oil!': 56,
#  'Excellent Purchase': 63,
#  'Excellent Water System': 60,
#  'Excellent olive oil, all natural': 10,
#  'Excellent quality': 32,
#  'Excellent value': 28,
#  'Excellent. Mine shipped fine': 2,
#  'Expensive': 26,
#  'Expensive!!!': 11,
#  'Extra excellent': 125,
#  'Extremely poor quality': 0,
#  'FSTG Multigrain chips are very good': 14,
#  'False Advertising': 0,
#  'Fantabulous Yocon.': 166,
#  'Fantastic Seasoning!': 9,
#  'Fantastic flavor': 43,
#  'Far too expensive': 51,
#  'Favorite coffee': 53,
#  'Five Stars': 142,
#  'For pastries that say fresher, lighter longer, use this conditioner': 123,
#  'Four Stars': 2,
#  'Fresh Product': 49,
#  'Fruity!': 21,
#  'Full Flavored': 96,
#  'GREAT': 76,
#  'Gardening aid which works! yes, for gardening': 13,
#  'Gave us stomach pains.': 29,
#  'Geat Snack!': 9,
#  'Get something better for your body.': 4,
#  'Gift': 0,
#  'Good Coffee': 10,
#  'Good Enough to Buy on Site': 152,
#  'Good Jerky Made Easy': 38,
#  'Good Product': 14,
#  'Good Quick Coffee - Recommended': 237,
#  'Good Service.': 5,
#  'Good Taste': 110,
#  'Good Tea': 112,
#  'Good Value, Easy Use': 230,
#  'Good but EXPENSIVE!': 37,
#  'Good cheap vegan meal option': 55,
#  'Good classic pretzel': 271,
#  'Good for cooking spicy': 23,
#  'Good for healthy': 45,
#  'Good memories': 2,
#  'Good rice': 48,
#  'Good stuff I must say': 82,
#  'Good stuff, eh?': 30,
#  'Good taste, not very hot though': 146,
#  'Good taste, very convenient and way too expensive!!': 125,
#  'Good taste, works fine!': 103,
#  'Good tea, the classic flavor': 38,
#  'Good value': 6,
#  'Good variety': 8,
#  'Good!': 100,
#  'Good, not great': 110,
#  'Good..........': 0,
#  'Grape Nuts': 59,
#  'Great Coffee Flavoring': 9,
#  'Great Experience': 1,
#  'Great Paleo snack and also can be cut up to ...': 174,
#  'Great Product': 9,
#  'Great Supplement !!': 75,
#  'Great Taste': 105,
#  'Great Variety': 89,
#  'Great as an iced beverage': 101,
#  'Great brand!': 227,
#  'Great coffee': 136,
#  'Great combination - without the salt': 11,
#  'Great day starter.': 168,
#  'Great detox tea!': 95,
#  'Great dietary supplement.': 16,
#  'Great everyday drinking tea': 218,
#  'Great flavor and another good way to enjoy any time of the day!': 220,
#  'Great for almost everything!': 12,
#  'Great for chili': 58,
#  'Great for kids and adults to as a snack on the go!': 76,
#  'Great for sensitive skin too': 78,
#  'Great for the price': 8,
#  'Great formula': 14,
#  'Great item with a couple flaws.': 166,
#  'Great mix of sealed and fresh variety of chips': 147,
#  'Great price': 1,
#  'Great price!': 3,
#  'Great products': 6,
#  'Great sparerib maranade.': 48,
#  'Great stuff': 149,
#  'Great taste': 95,
#  'Great taste, good energy': 136,
#  'Great tasting cookies with a cup of coffee!': 140,
#  'Great treat from Philadelphia': 64,
#  'Great variety': 181,
#  'Great variety!': 99,
#  'Handy and yummy salsa': 96,
#  'Hard Times Chili in your own home': 36,
#  'Hard to find': 8,
#  'Hard to find in USA': 4,
#  'Has an "acidy" like taste': 7,
#  'Hazel nuttiness': 22,
#  'Healthier option': 56,
#  'Healthy and tastes great. Ingredients Wholegrain Wheat (84%)': 53,
#  "Hershey's Bars": 38,
#  "Hershey's Pot Of Gold Nuts": 59,
#  "Hershey's at their best": 23,
#  'High quality baby food': 82,
#  'High-quality product': 95,
#  'Highly Recommended !!': 222,
#  'Highly recommended': 80,
#  'Hires Root Beer': 42,
#  'Hot Sauce good with Hot Wings': 5,
#  'How do I love thee - let me count the ways': 40,
#  "I Don't Like it": 3,
#  'I Just Love This Sugar-Free Green Energy Drink Powder.': 53,
#  'I Liked It. My Kids Hated It.': 142,
#  'I add them to Keurig Hot Chocolate': 191,
#  'I added this to red lentils and sweet potatoes to make a vegan hummus': 89,
#  'I am IN LOVE with this cereal!': 84,
#  'I approve of the new Quaker Oats': 33,
#  'I bought this for Hungarian letzso': 187,
#  "I don't hate it but I won't buy it again...": 220,
#  'I just wish we had more "Organic" Libby\'s veggies. ...': 8,
#  'I like it': 38,
#  'I like it very much': 12,
#  'I like the aroma of the coconut oil': 30,
#  'I like the taste': 123,
#  'I love honey.': 37,
#  'I love it': 78,
#  'I love it..............': 152,
#  'I love the 55% dark': 66,
#  'I love the full size pack': 14,
#  'I love these wraps,Its  is amazing': 185,
#  'I love this product!': 63,
#  'I love this stuff!': 154,
#  'I loved them in the 90s and ate them constantly': 44,
#  'I ordered two of these meals for my husband and ...': 11,
#  "I think this coffee is the best. I am spoiled and can't drink coffee anywhere else or any other brand!": 106,
#  'I was given a package by some customers who live ...': 1,
#  'I was not too crazy about this coconut juice; much better options available.': 117,
#  'I will always have it on my shelf.......': 3,
#  'I would normally use': 45,
#  "I'm Missing You Like Candy": 233,
#  "I'm addicted to this stuff! Yes they are a ...": 10,
#  "I'm inlove with this": 199,
#  "I'm married to a sexual tyrranosaurus!": 10,
#  "I'm warning you": 50,
#  'INGREDIENTS; Crunchy, tasty & compliments any flavor salad dressing...': 141,
#  "If they didn't notice, why tell them?": 64,
#  'If you have to switch to decaf, this is a good one': 59,
#  'If you like firmer gelatin': 100,
#  'If you like strong, this is the coffee for you': 42,
#  'Inaccurate product description': 0,
#  'Incredible!': 50,
#  'Indulge Yourself': 150,
#  'Instant at its best': 90,
#  'Is the flavor at the bottom?': 27,
#  'Is this seriously 97%?': 82,
#  'It is a good product': 16,
#  'It is named "hint" for a reason.': 48,
#  'It mixes up easily': 156,
#  'It turned out great!': 149,
#  "It's beautiful! !!!": 144,
#  "It's good": 18,
#  "It's ok.": 20,
#  'Just love it': 272,
#  'Just the perfect coffee!!!': 126,
#  'Just what I wanted': 123,
#  'Ketchup with extra zest!!': 115,
#  'Kick Back Earthy Cup of Goodness!': 83,
#  'Kids love it': 2,
#  'LOVE this stuff !!': 206,
#  'Lakewood Organic PURE Lemon Juice': 54,
#  'Like the Swiss Muesli': 49,
#  'Lipton not good anymore': 2,
#  'Look Forward To This Every Year': 68,
#  'Love It': 0,
#  'Love Pistacchios!': 117,
#  'Love Sees': 2,
#  'Love This': 197,
#  'Love buying tea in bulk': 213,
#  'Love it': 52,
#  'Love love Godiva': 47,
#  'Love love love this': 132,
#  'Love the miniature version of original saltines': 82,
#  'Love this one': 6,
#  'Love this particular brand': 214,
#  'Love this tea': 66,
#  'Love this. My dad used to buy turon every ...': 3,
#  'Loved the seeds!': 132,
#  'Loving this miniatures': 123,
#  'MMMMM!': 104,
#  'Maybe my sinuses are flared up worse than I realize': 42,
#  'Medicinal Tasting': 53,
#  'Meh it was ok': 16,
#  'Mehr Saffron is a Great!': 6,
#  'Mild flavor, great for baking.': 42,
#  "Miracle Tree's Mango + Moringa Tea is MY FAVORITE moringa tea": 160,
#  'Mmmmmmm....': 3,
#  'Most flavorful of all brands tried': 100,
#  'Most sought after white tea': 148,
#  'Must. Have. Musubi. Now.': 161,
#  'My 3 year old loves it and so do I': 106,
#  'My New Favorite': 139,
#  'My New Favorite Morning Tea': 152,
#  'My companion at work!': 117,
#  'My daughter and I made strawberry smoothie with this we ...': 81,
#  'My favorite coffee drink': 40,
#  'My favorite!': 93,
#  'My new favorite tea!': 64,
#  'My plants love it!': 7,
#  'My students will love them': 48,
#  'NOT GOOD': 4,
#  'Natural product': 201,
#  'New Grains Raisin Bread': 65,
#  'New update on Japanese Matcha from FDA - 3 Apr 2015 Warning': 1,
#  'Nice Bamboo salt holder': 1,
#  'Nice and fruity flavor': 16,
#  'Nice concept for using stevia': 216,
#  'Nice flavor': 131,
#  'Nice taste. I use it in my coffee': 27,
#  'No Caffeine crash!': 3,
#  'No Complaints!': 175,
#  'No coughing': 72,
#  'No fillers': 89,
#  'No flavor at all': 21,
#  'Noodles': 39,
#  'Northern European Blend': 23,
#  'Not As Good As Death Wish': 89,
#  'Not always easy to find at the grocery and not in large ...': 52,
#  'Not as good as they used to be': 234,
#  'Not as tasty as the untoasted!': 160,
#  'Not just for sore throats.': 119,
#  'Not my cup of coffee-tea': 64,
#  'Not real eggnog': 31,
#  'Not so good': 93,
#  'Not suitable for bean lover': 16,
#  'Not the Hostess product of my youth': 30,
#  'Nothing But Stevia': 136,
#  'Nothing for me to complain about': 15,
#  'Numi Tea set': 36,
#  'Nutty flavor': 8,
#  'OMG amazing taste': 21,
#  'Ok but not something I would rave about.': 5,
#  'Old school chocolate bar': 143,
#  'One of these and a glass of milk - great breakfast to start your day': 58,
#  'One star - I am worried about lead contamination in matcha from China.': 4,
#  'One star shows it all': 61,
#  'Onion!': 12,
#  'Only at amazon!': 20,
#  'Only one I use': 155,
#  'Only one better': 0,
#  'Optimal for Cappuccino, Espresso Machines (UPDATE: Be Aware of Roast Date!)': 64,
#  'Organic and Delicious': 87,
#  'Organic, but not cold-pressed': 91,
#  'Over Priced': 27,
#  'Overpaid for this one': 2,
#  'Overpowering citrus rind': 107,
#  'Overpriced': 7,
#  'Packaging is terrible': 2,
#  'Palm Kernel Oil': 3,
#  'Pasta was good and the quality you expect from Barilla': 76,
#  'Pasty noodle mash at the end of serving': 4,
#  'Perfect': 41,
#  'Perfect for my evryday sandwich!': 105,
#  "Perfect if You're in a Hurry and Tastes Good too": 66,
#  'Perfect muscle builder': 26,
#  'Perfect order!': 179,
#  'Perfect portions': 79,
#  "Perfect size for when you don't need to share. Quality not so good.": 32,
#  'Perfect snack for little ones with allergies': 124,
#  'Phenomenal quality and taste': 204,
#  'Pleasant but not great. Contains no sweeteners': 154,
#  'Popping up surprises': 18,
#  'Positve review': 107,
#  'Pretty Good': 157,
#  "Pretty tasty for a quick cook chili seasoning pack - the 'gluten free' is a nice side bonus": 77,
#  'Product works well': 22,
#  'Pumpkin Spice Flavor with a Kiss of White Chocolate': 130,
#  "Purchased because I thought it would have a floral taste...doesn't, but still not bad.": 128,
#  'Pure Pure Pure': 69,
#  'Qbubble is okay but really bad for you': 110,
#  'Quantity and Quality': 32,
#  'Questionable product!!!': 2,
#  'Really enjoyed this one': 144,
#  'Really good taste!': 98,
#  'Really tasty and relaxing.': 188,
#  'Red Plum Jam': 79,
#  'Refresh Your Taste Buds': 143,
#  'Ruffles All-dressed Chips': 34,
#  'SKinny Water': 47,
#  'SMALLER SIZE THAN PICTURED': 2,
#  'Saffron Rice': 2,
#  'Same as עלית': 5,
#  'Saturated fat': 64,
#  'Seriously?': 16,
#  'Ships fast, dissolves well': 60,
#  'Should be in every kitchen': 100,
#  'Simple Coffeeness': 199,
#  'Simply Awesome!': 123,
#  'Simply dreadful': 31,
#  'Simply terrible': 6,
#  'Sleepy time tea': 48,
#  'Smells like it is spoiled': 5,
#  'Smooth, Delicious Earl Grey Tea from your K Brewer': 196,
#  'So contradictory': 43,
#  'So good': 119,
#  'So hard to find and soooo good!': 159,
#  'So help me, God': 197,
#  'So... Where are the peanuts..': 173,
#  'Spicy!': 23,
#  'Splenda is a Delicious Artificial Sweetener, and We Recommend It!': 237,
#  'Success at Last': 67,
#  'Sugar crystal goodness': 86,
#  'Super fresh': 142,
#  'Super good for detox': 171,
#  'Super nummy': 54,
#  'Surprisingly Refreshing': 171,
#  'Surprisingly good': 189,
#  'Sweet taste and good price': 97,
#  'THE BEST!!!!!!!!!': 29,
#  'TOOOO GOOOODD!!!!!': 103,
#  'Talk About a Relaxing Tea!': 160,
#  'Tart, Tangy, Refreshing!': 80,
#  'Taste from My Childhood': 139,
#  'Taste funny': 67,
#  'Tastes great': 151,
#  'Tastes odd': 4,
#  'Tastes smoky, not like cherries': 49,
#  'Tasty': 161,
#  'Tasty addition to milk': 186,
#  'Tasty and Healthy ~ Great with Seltzer, Too!': 73,
#  'Tasty but annoying': 89,
#  'Tasty clams': 140,
#  'Terrible!': 4,
#  'Thank you!': 90,
#  "That's new": 14,
#  'The "Original" is the Better Choice. The garlic/lime variants are a bit heavy handed and don\'t match the quality of the Original': 65,
#  'The Apple of My Eye': 175,
#  'The Best': 24,
#  'The Best Chewy Candy I Have Ever Tasted...': 141,
#  'The Best Yet': 143,
#  'The best': 64,
#  'The best snack crackers around!': 119,
#  'The best!': 160,
#  'The first box': 3,
#  'The label had me lol the biz shipping +++++ coffee did not match foreplay': 102,
#  'The mussels are loving it': 58,
#  'The supreme chocolate': 198,
#  'The texture is not too dense': 56,
#  'The vinegar was too strong for my taste,': 113,
#  'The worst': 12,
#  'There is no other like it.': 90,
#  'These are different': 33,
#  'These are my favorite chocolate bar by Cadbury': 105,
#  'This Basket deserves a 5 star rating': 19,
#  'This is a great decaf coffee!': 42,
#  'This is a wonderful product. I make chicken soup the old-fashioned way': 85,
#  'This is great products': 56,
#  'This is great tea compared to others we have tried and a ...': 15,
#  'This is the best': 47,
#  'This is the best caramel/chocolate combination I have ever tasted': 132,
#  'This is the best rub ever!': 36,
#  'This pie crust is PHENOMINAL!!! I tried ...': 75,
#  'This poutch work sreally well': 72,
#  'This product is amazing! When I use it on my hair': 28,
#  'This product is natural': 83,
#  'This product is truly awesome': 99,
#  'This product may cause liver damage in some people at very low doses (over 1 teaspoon per day)': 67,
#  'This stuff is terrible': 7,
#  'This was very good.': 55,
#  'Threw it away.': 2,
#  'Thumbs Up': 84,
#  'To Die for Delicious': 26,
#  'Too much to handle': 4,
#  'Try these': 122,
#  'Ultra-lift Intensive or Ultra-lift Pro?': 96,
#  'Unique and very British!': 98,
#  'Unsafe for Human consumption.': 0,
#  'Used in beer recipe': 6,
#  'Useless, waste of money, use the Keurig adapter!': 181,
#  'VERY BITTER taste--needs to be WAY sweeter!': 249,
#  'Very Cool and Refreshing Product, You Must Buy Some Now.': 39,
#  'Very Disappointing!!': 92,
#  'Very Tasty': 94,
#  'Very Tasty and Nutricious Snack': 207,
#  'Very bland': 71,
#  "Very disappointed in manfacturer's quality": 156,
#  'Very easy': 60,
#  'Very good': 1,
#  'Very good but not great!': 139,
#  'Very good flavor': 131,
#  'Very good!': 56,
#  'Very happy with this purchase': 71,
#  'Very helpful in many areas': 101,
#  'Very nice': 97,
#  'Very nice Product': 73,
#  'Very tasty': 186,
#  'Very tasty, not too sweet': 101,
#  'Very worth it for the price.': 48,
#  'Very yummy': 252,
#  'Vibrant green color!': 12,
#  'WARNING: Do not buy!!!! Waste of Money and a DOES NOT WORK!!!': 25,
#  'Waddaya know': 10,
#  'Walkers are so delicious!': 49,
#  'Was kind of iffy about trying this kind of thing ...': 7,
#  'Was looking for this!': 188,
#  'Way to much salt for me': 33,
#  'We liked these': 77,
#  'We love Tim Hortons': 219,
#  'We love this couscous...': 22,
#  'We will definitely be back for more!': 118,
#  'What a blast from the past': 6,
#  'What a great price on a pound of the best tasting jelly beans EVER!': 32,
#  'What happened?': 7,
#  'What the heck is this?': 78,
#  'Why Not?': 105,
#  'Wonderful': 44,
#  'Works great': 2,
#  'Worst taste I have ever tasted in my life': 13,
#  'YUMMYYYYY': 0,
#  'Yeah I would say the marinade is good.': 0,
#  "You won't be disappointed": 115,
#  "You won't regret this purchase!": 41,
#  'Yum': 134,
#  'Yum Yums': 162,
#  'Yummy': 121,
#  'Yummy but thick': 176,
#  'Yummy!': 173,
#  'Yummy, But They Are More Chocolate than Birthday Cake. No Frosting Flavor To Them': 37,
#  'a must have': 265,
#  'addictive candies': 28,
#  'amazing food': 86,
#  'amazing taste': 35,
#  'amazing! I ordered them for Thanksgiving': 41,
#  'and like eating tuna I feel a kick in my system ...': 242,
#  'another value i love': 50,
#  'awful Chemical tasting': 10,
#  'baapd and low quality': 7,
#  'best flavor': 158,
#  'best honey out there': 34,
#  'best quality, real Ceylon Cinnamon': 161,
#  'best snacking': 106,
#  'big jug': 59,
#  'bottle was out of date': 5,
#  "but it's about the best you can buy": 292,
#  'classic': 139,
#  'cleaner alternative to Jello.  Not as firm or brightly colored, but SO much better for you!': 170,
#  'close enough for govt work. :-O': 172,
#  'coffie': 71,
#  'convenient': 78,
#  'convenient and tasty': 60,
#  'curing salts': 27,
#  'delicious': 92,
#  'delicious coffee': 217,
#  'delicious rice!!': 46,
#  'deluctable': 87,
#  'difficult to use': 1,
#  'eat healthy!': 40,
#  'excelent for my shakes and dessert.': 204,
#  'excellent': 20,
#  'excellent juniper tree': 1,
#  'excllent product, outrageous price': 148,
#  'fabulous product.': 125,
#  'family favorite': 1,
#  'far too thin': 3,
#  'favorite': 73,
#  'fragrant and tasty': 165,
#  'fresh and delicious.': 44,
#  'fresh water': 15,
#  'good': 27,
#  'good heat': 6,
#  'good in a pinch': 82,
#  'good product': 68,
#  'good sub': 64,
#  'great for my kids.': 79,
#  'great for the holiday season': 73,
#  'great product': 84,
#  'great taste': 51,
#  'grove square': 7,
#  'he chocolates are rich in flavor, they sent me ...': 26,
#  'heaven in my mouth': 15,
#  "i don't like this flavors": 102,
#  "if you're used to Rapid Rise ...": 37,
#  'increased milk product but not without side effects': 51,
#  'it is all about how you brew': 145,
#  'it lasted a year then melted': 4,
#  "it's economical.": 154,
#  "it's hard to eat just one serving of these!": 25,
#  "it's quite expensive although it does taste good. It has a nice roasted flavor without the ...": 53,
#  'its delicious': 118,
#  'its healthy and good taste': 2,
#  'its healthy product': 61,
#  'love it': 9,
#  'lovely and tasty gummy': 12,
#  'loves this product.': 8,
#  'met expectations': 73,
#  'more than worth it': 34,
#  'morning jogging': 2,
#  'mouth-watering!': 86,
#  'my kids love it': 71,
#  'natural and tasty': 29,
#  'nearly unbearable': 16,
#  'nice 20-ouncer': 48,
#  'no scent whatsoever': 7,
#  'not bad': 113,
#  'not digestable': 199,
#  'not sold': 13,
#  'not working': 43,
#  'okay': 25,
#  'only for me': 13,
#  'out of 4 bags @ 12oz each 2 were great and 2 were': 29,
#  'paella': 9,
#  'passion fruit nectar': 0,
#  'perfect hot sauce': 42,
#  'poor taste': 36,
#  'powdery not much green tea flavor': 12,
#  'power food': 0,
#  'produced a flavored coffee that I actually enjoy - the Maple Sleigh': 162,
#  'really good and easy': 2,
#  'really good taste': 196,
#  'second choice': 12,
#  'still good': 188,
#  'strong smell, stronger taste': 29,
#  'sugar rush!!!': 73,
#  'super SUPER sweet': 178,
#  'taste old and are not edible.': 109,
#  'tastes great': 37,
#  'tasty': 104,
#  'tasty as crap': 32,
#  "that couldn't be any good, could it": 143,
#  'the easy cap it is so CUTE!!': 186,
#  'the only one': 23,
#  'this stuff is amazing! I was worried that it would taste terrible ...': 101,
#  'very durable': 5,
#  'very few nuts': 20,
#  'very good and satisfying grape flavor for your sweet tooth': 115,
#  'very good loose leaf tea': 163,
#  'very nice bags': 17,
#  'very pretty': 73,
#  'very rich black tea': 118,
#  'well packaged and on time like the product.': 16,
#  'what I was looking for': 21,
#  'wonderful': 1,
#  'works well': 106,
#  'worth the price': 38,
#  'yikes': 11,
#  'you\'re much better off trying trying to find "natural" chocolate if you ...': 56,
#  'yum': 2,
#  'yum and no added sugar': 105,
#  'yum yumm!': 153,
#  'yummy': 104,
#  'yummyyyy....:)': 34}
